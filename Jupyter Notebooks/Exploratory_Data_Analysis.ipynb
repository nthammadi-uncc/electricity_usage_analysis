# %% [markdown]
# # Electricity Usage Analytics of all states in USA
# ## Exploratory Data Analysis and Data Preprocessing

# %% [markdown]
# #### Import Libraries and Packages

# %%
# Import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

# %%
# Function to read data from URL
def read_data_from_URL(url):
    df=pd.read_csv(url)
    return df

# %%
#set up data urls from github
parent_url='https://raw.githubusercontent.com/nthammadi-uncc/electricity_usage_analysis/main/Data/'
electric_price_url=parent_url+'avgprice_annual.csv'
monthly_consumption_url=parent_url+'consumption_monthly.csv'
annual_customers_url=parent_url+'customers_annual.csv'
annual_emission_url=parent_url+'emission_annual.csv'
monthly_generation_url=parent_url+'generation_monthly.csv'
median_household_income_url=parent_url+'median_household_income.csv'
presidential_election_url=parent_url+'presidential_election_results.csv'

# %% [markdown]
# ### Get Electricity Price data

# %%
price_df = read_data_from_URL(electric_price_url)
price_df.head()
# Out:
#    Year State Industry Sector Category  Residential  Commercial  Industrial  \
# 0  2020    AK  Total Electric Industry        22.57       19.58       15.88
# 1  2020    AL  Total Electric Industry        12.58       11.55        5.87
# 2  2020    AR  Total Electric Industry        10.41        8.61        5.89
# 3  2020    AZ  Total Electric Industry        12.27       10.11        6.07
# 4  2020    CA  Total Electric Industry        20.45       17.53       14.27
#
#    Transportation  Other  Total
# 0            0.00    NaN  19.82
# 1            0.00    NaN   9.84
# 2           13.32    NaN   8.32
# 3            9.38    NaN  10.44
# 4           10.07    NaN  18.00

# %% [markdown]
# ### Get Monthly Electricity Consumption & Generation data

# %%
consumption_df = read_data_from_URL(monthly_consumption_url)
consumption_df.head()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3338: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
#    YEAR  MONTH STATE                         TYPE_OF_PRODUCER  \
# 0  2001      1    AK            Total Electric Power Industry
# 1  2001      1    AK            Total Electric Power Industry
# 2  2001      1    AK            Total Electric Power Industry
# 3  2001      1    AK  Electric Generators, Electric Utilities
# 4  2001      1    AK  Electric Generators, Electric Utilities
#
#          ENERGY_SOURCE CONSUMPTION_MWh
# 0    Coal (Short Tons)        47615.00
# 1  Petroleum (Barrels)       124998.00
# 2    Natural Gas (Mcf)      3941267.00
# 3    Coal (Short Tons)        16535.00
# 4  Petroleum (Barrels)       114198.00

# %%
generation_df = read_data_from_URL(monthly_generation_url)
generation_df.head()
# Out:
#    YEAR  MONTH STATE               TYPE_OF_PRODUCER  \
# 0  2001      1    AK  Total Electric Power Industry
# 1  2001      1    AK  Total Electric Power Industry
# 2  2001      1    AK  Total Electric Power Industry
# 3  2001      1    AK  Total Electric Power Industry
# 4  2001      1    AK  Total Electric Power Industry
#
#                 ENERGY_SOURCE  GENERATION_MWh
# 0                        Coal         46903.0
# 1                   Petroleum         71085.0
# 2                 Natural Gas        367521.0
# 3  Hydroelectric Conventional        104549.0
# 4                        Wind            87.0

# %% [markdown]
# ### Get Annual Customers(Consumers) of Electricity Data

# %%
customers_df = read_data_from_URL(annual_customers_url)
customers_df.head()
# Out:
#    Year State Industry Sector Category  Residential  Commercial  Industrial  \
# 0  2020    AK  Total Electric Industry     315208.0     61993.0      1129.0
# 1  2020    AL  Total Electric Industry    2280741.0    371888.0      7240.0
# 2  2020    AR  Total Electric Industry    1413490.0    197869.0     35978.0
# 3  2020    AZ  Total Electric Industry    2896339.0    331229.0      7595.0
# 4  2020    CA  Total Electric Industry   13834719.0   1725533.0    148130.0
#
#    Transportation  Other       Total
# 0             0.0    NaN    378330.0
# 1             0.0    NaN   2659869.0
# 2             2.0    NaN   1647339.0
# 3             2.0    NaN   3235165.0
# 4            13.0    NaN  15708395.0

# %% [markdown]
# ### Get Annual Emissions Data(CO2, SO2,NOx)

# %%
emission_df = read_data_from_URL(annual_emission_url)
emission_df.head()
# Out:
#    Year State         Producer Type Energy Source  CO2\n(Metric Tons)  \
# 0  1990    AK      Commercial Cogen   All Sources            824004.0
# 1  1990    AK      Commercial Cogen          Coal            821929.0
# 2  1990    AK      Commercial Cogen     Petroleum              2075.0
# 3  1990    AK  Commercial Non-Cogen   All Sources                 0.0
# 4  1990    AK  Commercial Non-Cogen     Petroleum                 0.0
#
#    SO2\n(Metric Tons)  NOx\n(Metric Tons)
# 0             13198.0              3011.0
# 1             13191.0              3009.0
# 2                 6.0                 2.0
# 3               149.0                42.0
# 4               149.0                42.0

# %% [markdown]
# ### Get Median Household Income Data

# %%
median_income_df = read_data_from_URL(median_household_income_url)
median_income_df.head()
# Out:
#            State     2020     2019     2018     2017     2016     2015  \
# 0  United States  67521.0  68703.0  63179.0  61136.0  59039.0  56516.0
# 1        Alabama  54393.0  56200.0  49936.0  50865.0  47221.0  44509.0
# 2         Alaska  74476.0  78394.0  68734.0  77987.0  75723.0  75112.0
# 3        Arizona  66628.0  70674.0  62283.0  59700.0  57100.0  52248.0
# 4       Arkansas  50540.0  54539.0  49781.0  49751.0  45907.0  42798.0
#
#       2014     2013     2012  ...     2009     2008     2007     2006  \
# 0  53657.0  53585.0  51017.0  ...  49777.0  50303.0  50233.0  48201.0
# 1  42278.0  47320.0  43464.0  ...  39980.0  44476.0  42212.0  37952.0
# 2  67629.0  72472.0  63648.0  ...  61604.0  63989.0  62993.0  56418.0
# 3  49254.0  52611.0  47044.0  ...  45739.0  46914.0  47215.0  46657.0
# 4  44922.0  39376.0  39018.0  ...  36538.0  39586.0  40795.0  37057.0
#
#       2005     2004     2003     2002     2001     2000
# 0  46326.0  44334.0  43318.0  42409.0  42228.0  41990.0
# 1  37150.0  36629.0  37255.0  37603.0  35160.0  35424.0
# 2  55891.0  55063.0  51837.0  52774.0  57363.0  52847.0
# 3  45245.0  43846.0  41166.0  39734.0  42704.0  39783.0
# 4  36658.0  34984.0  32002.0  32387.0  33339.0  29697.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Get Presidential Election Results Data

# %%
election_results_df = read_data_from_URL(presidential_election_url)
election_results_df.head()
# Out:
#    year    state state_po        candidate party_simplified writein  \
# 0  2000  ALABAMA       AL  BUSH, GEORGE W.       REPUBLICAN   False
# 1  2000  ALABAMA       AL         GORE, AL         DEMOCRAT   False
# 2  2000  ALABAMA       AL              NaN            OTHER   False
# 3  2000  ALABAMA       AL    BROWNE, HARRY      LIBERTARIAN   False
# 4  2000  ALABAMA       AL              NaN            OTHER    True
#
#    candidate_votes  total_votes
# 0           941173      1666272
# 1           692611      1666272
# 2            25896      1666272
# 3             5893      1666272
# 4              699      1666272
